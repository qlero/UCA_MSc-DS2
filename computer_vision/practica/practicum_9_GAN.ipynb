# %% [markdown]
# # Practical Session - GAN
#
# The goal of this exercice is to create a DCGAN to generate Manga faces.
#
# ## Roadline :
# - Setup the workspace
#   1. Enable the **GPU**
#   2. Install and import the **Pytorch library**
#
#
# - DCGAN implementation in Pytorch explained
#   0. Import libraries needed
#   1. Load and Prepare dataset
#   2. Generator
#   3. Discriminator
#   4. Generator - Discriminator Loss
#   5. Optimizer
#   6. Train

# %% [markdown]
# ## Setup the workplace

# %% [markdown]
# 1. Enable the **GPU**
#
#
# Getting Starting, you need to **enable** the GPU as hardware accelerator :
#
#              »Edit »Notebook settings »select GPU » SAVE.
#
#
# and check the GPU type :

# %%
# !nvidia-smi
# Out:
# Tue Nov 16 14:29:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    36W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
#   2. **install** and **import** the *PyTorch library*

# %%
#!pip3 install torch torchvision
import torch

# %% [markdown]
# ## DCGAN implementation in Pytorch

# %% [markdown]
#   ### 0. Libraries importation
#
# For this project, we need to import several packages

# %%
import numpy as np
import os
import random
import glob
import time

import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision.utils import make_grid
import torchvision.utils as vutils

from PIL import Image
import matplotlib.animation as animation
from IPython.display import HTML
from IPython import display
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Load and Prepare dataset

# %% [markdown]
# 1) Download the Manga face dataset by cloning the github project of Yaohui Wang
#
# 2) and then unzip the images folder
#
# 3) To take a look at the dataset, display the image you want and the associated size
#
# 4) Prepare the loaded MangaFace dataset as training set
#
# 5) Show the size of the training set

# %%
# 1) download dataset
# !git clone https://gitlab.inria.fr/yaowang/gan_class_images.git
# Out:
# Cloning into 'gan_class_images'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), done.

# %%
# !ls
# Out:
# gan_class_images  sample_data

# %%
# !cd gan_class_images

# %%
# 2) cd images folder and unzip 
# !cd gan_class_images;unzip images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/32488.jpg
#   inflating: images/14625.jpg
#   inflating: images/6385.jpg
#   inflating: images/7921.jpg
#   inflating: images/18321.jpg
#   inflating: images/32888.jpg
#   inflating: images/1003.jpg
#   inflating: images/16799.jpg
#   inflating: images/8748.jpg
#   inflating: images/8425.jpg
#   inflating: images/14554.jpg
#   inflating: images/14586.jpg
#   inflating: images/36729.jpg
#   inflating: images/35430.jpg
#   inflating: images/10188.jpg
#   inflating: images/1673.jpg
#   inflating: images/36356.jpg
#   inflating: images/27328.jpg
#   inflating: images/1712.jpg
#   inflating: images/440.jpg
#   inflating: images/30384.jpg
#   inflating: images/27859.jpg
#   inflating: images/28374.jpg
#   inflating: images/14321.jpg
#   inflating: images/12997.jpg
#   inflating: images/30376.jpg
#   inflating: images/32084.jpg
#   inflating: images/26612.jpg
#   inflating: images/17967.jpg
#   inflating: images/13578.jpg
#   inflating: images/1866.jpg
#   inflating: images/9780.jpg
#   inflating: images/1782.jpg
#   inflating: images/4083.jpg
#   inflating: images/27741.jpg
#   inflating: images/22602.jpg
#   inflating: images/20243.jpg
#   inflating: images/4318.jpg
#   inflating: images/28488.jpg
#   inflating: images/5220.jpg
#   inflating: images/26595.jpg
#   inflating: images/11977.jpg
#   inflating: images/23710.jpg
#   inflating: images/5381.jpg
#   inflating: images/27447.jpg
#   inflating: images/489.jpg
#   inflating: images/12166.jpg
#   inflating: images/3730.jpg
#   inflating: images/23567.jpg
#   inflating: images/4503.jpg
#   inflating: images/4374.jpg
#   inflating: images/15457.jpg
#   inflating: images/29773.jpg
#   inflating: images/36648.jpg
#   inflating: images/9480.jpg
#   inflating: images/29667.jpg
#   inflating: images/26638.jpg
#   inflating: images/2613.jpg
#   inflating: images/32788.jpg
#   inflating: images/296.jpg
#   inflating: images/27259.jpg
#   inflating: images/7378.jpg
#   inflating: images/10225.jpg
#   inflating: images/24431.jpg
#   inflating: images/25165.jpg
#   inflating: images/16337.jpg
#   inflating: images/13535.jpg
#   inflating: images/26774.jpg
#   inflating: images/16562.jpg
#   inflating: images/4788.jpg
#   inflating: images/29026.jpg
#   inflating: images/26219.jpg
#   inflating: images/6519.jpg
#   inflating: images/11502.jpg
#   inflating: images/19451.jpg
#   inflating: images/15405.jpg
#   inflating: images/33373.jpg
#   inflating: images/2283.jpg
#   inflating: images/35390.jpg
#   inflating: images/7756.jpg
#   inflating: images/36683.jpg
#   inflating: images/34977.jpg
#   inflating: images/18015.jpg
#   inflating: images/10593.jpg
#   inflating: images/26472.jpg
#   inflating: images/19937.jpg
#   inflating: images/7222.jpg
#   inflating: images/6710.jpg
#   inflating: images/34392.jpg
#   inflating: images/11614.jpg
#   inflating: images/14196.jpg
#   inflating: images/981.jpg
#   inflating: images/26559.jpg
#   inflating: images/17442.jpg
#   inflating: images/26928.jpg
#   inflating: images/26922.jpg
#   inflating: images/3064.jpg
#   inflating: images/8672.jpg
#   inflating: images/14646.jpg
#   inflating: images/18234.jpg
#   inflating: images/20774.jpg
#   inflating: images/9127.jpg
#   inflating: images/24307.jpg
#   inflating: images/17436.jpg
#   inflating: images/17327.jpg
#   inflating: images/35393.jpg
#   inflating: images/7369.jpg
#   inflating: images/23545.jpg
#   inflating: images/3990.jpg
#   inflating: images/17803.jpg
#   inflating: images/30850.jpg
#   inflating: images/2033.jpg
#   inflating: images/35471.jpg
#   inflating: images/2435.jpg
#   inflating: images/3756.jpg
#   inflating: images/4716.jpg
#   inflating: images/35468.jpg
#   inflating: images/10786.jpg
#   inflating: images/36417.jpg
#   inflating: images/4456.jpg
#   inflating: images/25610.jpg
#   inflating: images/10629.jpg
#   inflating: images/4151.jpg
#   inflating: images/14049.jpg
#   inflating: images/17090.jpg
#   inflating: images/17985.jpg
#   inflating: images/23921.jpg
#   inflating: images/22809.jpg
#   inflating: images/4448.jpg
#   inflating: images/30426.jpg
#   inflating: images/4099.jpg
#   inflating: images/12237.jpg
#   inflating: images/28755.jpg
#   inflating: images/35159.jpg
#   inflating: images/25670.jpg
#   inflating: images/31361.jpg
#   inflating: images/21668.jpg
#   inflating: images/35759.jpg
#   inflating: images/14229.jpg
#   inflating: images/21996.jpg
#   inflating: images/21083.jpg
#   inflating: images/27004.jpg
#   inflating: images/8245.jpg
#   inflating: images/25572.jpg
#   inflating: images/27104.jpg
#   inflating: images/11038.jpg
#   inflating: images/33093.jpg
#   inflating: images/30837.jpg
#   inflating: images/23255.jpg
#   inflating: images/5996.jpg
#   inflating: images/32062.jpg
#   inflating: images/7846.jpg
#   inflating: images/18414.jpg
#   inflating: images/32478.jpg
#   inflating: images/22497.jpg
#   inflating: images/32211.jpg
#   inflating: images/5566.jpg
#   inflating: images/13679.jpg
#   inflating: images/27261.jpg
#   inflating: images/5768.jpg
#   inflating: images/22973.jpg
#   inflating: images/24381.jpg
#   inflating: images/2139.jpg
#   inflating: images/25413.jpg
#   inflating: images/16378.jpg
#   inflating: images/18859.jpg
#   inflating: images/16308.jpg
#   inflating: images/29086.jpg
#   inflating: images/32725.jpg
#   inflating: images/28938.jpg
#   inflating: images/33684.jpg
#   inflating: images/13223.jpg
#   inflating: images/36393.jpg
#   inflating: images/5706.jpg
#   inflating: images/24159.jpg
#   inflating: images/35383.jpg
#   inflating: images/21194.jpg
#   inflating: images/810.jpg
#   inflating: images/30352.jpg
#   inflating: images/31011.jpg
#   inflating: images/26845.jpg
#   inflating: images/20789.jpg
#   inflating: images/17526.jpg
#   inflating: images/29113.jpg
#   inflating: images/36138.jpg
#   inflating: images/32755.jpg
#   inflating: images/31060.jpg
#   inflating: images/4272.jpg
#   inflating: images/28641.jpg
#   inflating: images/28521.jpg
#   inflating: images/23313.jpg
#   inflating: images/31227.jpg
#   inflating: images/25280.jpg
#   inflating: images/18322.jpg
#   inflating: images/32038.jpg
#   inflating: images/10226.jpg
#   inflating: images/25802.jpg
#   inflating: images/22423.jpg
#   inflating: images/11357.jpg
#   inflating: images/4428.jpg
#   inflating: images/4703.jpg
#   inflating: images/34858.jpg
#   inflating: images/27966.jpg
#   inflating: images/17448.jpg
#   inflating: images/23337.jpg
#   inflating: images/28454.jpg
#   inflating: images/20943.jpg
#   inflating: images/32496.jpg
#   inflating: images/23006.jpg
#   inflating: images/1391.jpg
#   inflating: images/36202.jpg
#   inflating: images/16271.jpg
#   inflating: images/29898.jpg
#   inflating: images/15400.jpg
#   inflating: images/27058.jpg
#   inflating: images/5913.jpg
#   inflating: images/12458.jpg
#   inflating: images/9129.jpg
#   inflating: images/21889.jpg
#   inflating: images/21601.jpg
#   inflating: images/9878.jpg
#   inflating: images/36563.jpg
#   inflating: images/24177.jpg
#   inflating: images/6124.jpg
#   inflating: images/17620.jpg
#   inflating: images/30442.jpg
#   inflating: images/28444.jpg
#   inflating: images/29746.jpg
#   inflating: images/31111.jpg
#   inflating: images/29999.jpg
#   inflating: images/16925.jpg
#   inflating: images/15495.jpg
#   inflating: images/12326.jpg
#   inflating: images/32596.jpg
#   inflating: images/26772.jpg
#   inflating: images/5486.jpg
#   inflating: images/6926.jpg
#   inflating: images/8492.jpg
#   inflating: images/33689.jpg
#   inflating: images/9490.jpg
#   inflating: images/35942.jpg
#   inflating: images/5116.jpg
#   inflating: images/9520.jpg
#   inflating: images/22027.jpg
#   inflating: images/28257.jpg
#   inflating: images/19683.jpg
#   inflating: images/23036.jpg
#   inflating: images/20779.jpg
#   inflating: images/19118.jpg
#   inflating: images/36458.jpg
#   inflating: images/12567.jpg
#   inflating: images/18763.jpg
#   inflating: images/12748.jpg
#   inflating: images/21109.jpg
#   inflating: images/7047.jpg
#   inflating: images/11723.jpg
#   inflating: images/22910.jpg
#   inflating: images/26268.jpg
#   inflating: images/6604.jpg
#   inflating: images/13332.jpg
#   inflating: images/8985.jpg
#   inflating: images/8192.jpg
#   inflating: images/9268.jpg
#   inflating: images/14915.jpg
#   inflating: images/18445.jpg
#   inflating: images/25188.jpg
#   inflating: images/524.jpg
#   inflating: images/34171.jpg
#   inflating: images/33784.jpg
#   inflating: images/4937.jpg
#   inflating: images/8369.jpg
#   inflating: images/19882.jpg
#   inflating: images/36669.jpg
#   inflating: images/19649.jpg
#   inflating: images/6902.jpg
#   inflating: images/24568.jpg
#   inflating: images/17716.jpg
#   inflating: images/31784.jpg
#   inflating: images/17245.jpg
#   inflating: images/23851.jpg
#   inflating: images/36518.jpg
#   inflating: images/12303.jpg
#   inflating: images/22615.jpg
#   inflating: images/15132.jpg
#   inflating: images/24752.jpg
#   inflating: images/31417.jpg
#   inflating: images/36263.jpg
#   inflating: images/16528.jpg
#   inflating: images/3805.jpg
#   inflating: images/35050.jpg
#   inflating: images/4834.jpg
#   inflating: images/17815.jpg
#   inflating: images/16316.jpg
#   inflating: images/24337.jpg
#   inflating: images/3981.jpg
#   inflating: images/31030.jpg
#   inflating: images/18146.jpg
#   inflating: images/29245.jpg
#   inflating: images/22727.jpg
#   inflating: images/13387.jpg
#   inflating: images/28530.jpg
#   inflating: images/21790.jpg
#   inflating: images/2902.jpg
#   inflating: images/1017.jpg
#   inflating: images/31641.jpg
#   inflating: images/10296.jpg
#   inflating: images/7617.jpg
#   inflating: images/9378.jpg
#   inflating: images/16932.jpg
#   inflating: images/4375.jpg
#   inflating: images/9074.jpg
#   inflating: images/22197.jpg
#   inflating: images/22235.jpg
#   inflating: images/12570.jpg
#   inflating: images/5678.jpg
#   inflating: images/2699.jpg
#   inflating: images/12347.jpg
#   inflating: images/25311.jpg
#   inflating: images/30797.jpg
#   inflating: images/20862.jpg
#   inflating: images/34838.jpg
#   inflating: images/26961.jpg
#   inflating: images/33708.jpg
#   inflating: images/17505.jpg
#   inflating: images/32179.jpg
#   inflating: images/1936.jpg
#   inflating: images/16654.jpg
#   inflating: images/6308.jpg
#   inflating: images/28673.jpg
#   inflating: images/6273.jpg
#   inflating: images/19097.jpg
#   inflating: images/20066.jpg
#   inflating: images/3896.jpg
#   inflating: images/20929.jpg
#   inflating: images/5561.jpg
#   inflating: images/13555.jpg
#   inflating: images/35474.jpg
#   inflating: images/23365.jpg
#   inflating: images/4768.jpg
#   inflating: images/35966.jpg
#   inflating: images/19496.jpg
#   inflating: images/18740.jpg
#   inflating: images/34222.jpg
#   inflating: images/32276.jpg
#   inflating: images/6796.jpg
#   inflating: images/1327.jpg
#   inflating: images/31177.jpg
#   inflating: images/33819.jpg
#   inflating: images/23095.jpg
#   inflating: images/15597.jpg
#   inflating: images/8841.jpg
#   inflating: images/2638.jpg
#   inflating: images/18184.jpg
#   inflating: images/31643.jpg
#   inflating: images/24828.jpg
#   inflating: images/29365.jpg
#   inflating: images/29371.jpg
#   inflating: images/23503.jpg
#   inflating: images/22546.jpg
#   inflating: images/21125.jpg
#   inflating: images/7643.jpg
#   inflating: images/21420.jpg
#   inflating: images/5253.jpg
#   inflating: images/1951.jpg
#   inflating: images/5613.jpg
#   inflating: images/18265.jpg
#   inflating: images/32730.jpg
#   inflating: images/14143.jpg
#   inflating: images/27524.jpg
#   inflating: images/9285.jpg
#   inflating: images/12370.jpg
#   inflating: images/34602.jpg
#   inflating: images/25328.jpg
#   inflating: images/20182.jpg
#   inflating: images/21403.jpg
#   inflating: images/8229.jpg
#   inflating: images/3368.jpg
#   inflating: images/28997.jpg
#   inflating: images/3997.jpg
#   inflating: images/6624.jpg
#   inflating: images/24098.jpg
#   inflating: images/25771.jpg
#   inflating: images/1135.jpg
#   inflating: images/11373.jpg
#   inflating: images/11296.jpg
#   inflating: images/5332.jpg
#   inflating: images/32612.jpg
#   inflating: images/11152.jpg
#   inflating: images/16716.jpg
#   inflating: images/29708.jpg
#   inflating: images/11623.jpg
#   inflating: images/29992.jpg
#   inflating: images/899.jpg
#   inflating: images/34305.jpg
#   inflating: images/92.jpg
#   inflating: images/25929.jpg
#   inflating: images/30200.jpg
#   inflating: images/32965.jpg
#   inflating: images/31692.jpg
#   inflating: images/24805.jpg
#   inflating: images/26890.jpg
#   inflating: images/27112.jpg
#   inflating: images/24259.jpg
#   inflating: images/23792.jpg
#   inflating: images/36525.jpg
#   inflating: images/32907.jpg
#   inflating: images/34377.jpg
#   inflating: images/22830.jpg
#   inflating: images/12595.jpg
#   inflating: images/36730.jpg
#   inflating: images/16245.jpg
#   inflating: images/32714.jpg
#   inflating: images/6552.jpg
#   inflating: images/9740.jpg
#   inflating: images/20076.jpg
#   inflating: images/7695.jpg
#   inflating: images/19134.jpg
#   inflating: images/27390.jpg
#   inflating: images/8782.jpg
#   inflating: images/9907.jpg
#   inflating: images/384.jpg
#   inflating: images/2027.jpg
#   inflating: images/13156.jpg
#   inflating: images/19381.jpg
#   inflating: images/15370.jpg
#   inflating: images/29135.jpg
#   inflating: images/10627.jpg
#   inflating: images/10005.jpg
#   inflating: images/25779.jpg
#   inflating: images/4241.jpg
#   inflating: images/14841.jpg
#   inflating: images/5877.jpg
#   inflating: images/27880.jpg
#   inflating: images/959.jpg
#   inflating: images/1020.jpg
#   inflating: images/19435.jpg
#   inflating: images/4724.jpg
#   inflating: images/4255.jpg
#   inflating: images/6139.jpg
#   inflating: images/8137.jpg
#   inflating: images/20394.jpg
#   inflating: images/21401.jpg
#   inflating: images/31881.jpg
#   inflating: images/22967.jpg
#   inflating: images/25279.jpg
#   inflating: images/19449.jpg
#   inflating: images/4780.jpg
#   inflating: images/6437.jpg
#   inflating: images/11222.jpg
#   inflating: images/24511.jpg
#   inflating: images/3475.jpg
#   inflating: images/7935.jpg
#   inflating: images/20421.jpg
#   inflating: images/18086.jpg
#   inflating: images/35211.jpg
#   inflating: images/23118.jpg
#   inflating: images/32528.jpg
#   inflating: images/208.jpg
#   inflating: images/5774.jpg
#   inflating: images/16725.jpg
#   inflating: images/28630.jpg
#   inflating: images/21504.jpg
#   inflating: images/3594.jpg
#   inflating: images/11612.jpg
#   inflating: images/29072.jpg
#   inflating: images/21631.jpg
#   inflating: images/35326.jpg
#   inflating: images/7311.jpg
#   inflating: images/23114.jpg
#   inflating: images/775.jpg
#   inflating: images/4398.jpg
#   inflating: images/1945.jpg
#   inflating: images/19499.jpg
#   inflating: images/17437.jpg
#   inflating: images/28089.jpg
#   inflating: images/13874.jpg
#   inflating: images/29329.jpg
#   inflating: images/10718.jpg
#   inflating: images/25242.jpg
#   inflating: images/3002.jpg
#   inflating: images/6204.jpg
#   inflating: images/27397.jpg
#   inflating: images/32007.jpg
#   inflating: images/230.jpg
#   inflating: images/11261.jpg
#   inflating: images/9886.jpg
#   inflating: images/30532.jpg
#   inflating: images/5117.jpg
#   inflating: images/11031.jpg
#   inflating: images/9893.jpg
#   inflating: images/3304.jpg
#   inflating: images/35212.jpg
#   inflating: images/28873.jpg
#   inflating: images/35048.jpg
#   inflating: images/31546.jpg
#   inflating: images/27445.jpg
#   inflating: images/17189.jpg
#   inflating: images/417.jpg
#   inflating: images/5750.jpg
#   inflating: images/35910.jpg
#   inflating: images/2444.jpg
#   inflating: images/35810.jpg
#   inflating: images/36038.jpg
#   inflating: images/9294.jpg
#   inflating: images/28410.jpg
#   inflating: images/36715.jpg
#   inflating: images/7097.jpg
#   inflating: images/34001.jpg
#   inflating: images/6543.jpg
#   inflating: images/25733.jpg
#   inflating: images/35278.jpg
#   inflating: images/20878.jpg
#   inflating: images/26093.jpg
#   inflating: images/9443.jpg
#   inflating: images/23625.jpg
#   inflating: images/9887.jpg
#   inflating: images/17917.jpg
#   inflating: images/7620.jpg
#   inflating: images/8975.jpg
#   inflating: images/22697.jpg
#   inflating: images/14611.jpg
#   inflating: images/33830.jpg
#   inflating: images/24949.jpg
#   inflating: images/965.jpg
#   inflating: images/23937.jpg
#   inflating: images/14481.jpg
#   inflating: images/11409.jpg
#   inflating: images/13883.jpg
#   inflating: images/14382.jpg
#   inflating: images/26345.jpg
#   inflating: images/29183.jpg
#   inflating: images/12497.jpg
#   inflating: images/22225.jpg
#   inflating: images/327.jpg
#   inflating: images/12388.jpg
#   inflating: images/22959.jpg
#   inflating: images/2302.jpg
#   inflating: images/9347.jpg
#   inflating: images/31006.jpg
#   inflating: images/5336.jpg
#   inflating: images/21070.jpg
#   inflating: images/0.jpg
#   inflating: images/20067.jpg
#   inflating: images/12435.jpg
#   inflating: images/17366.jpg
#   inflating: images/14295.jpg
#   inflating: images/7625.jpg
#   inflating: images/26990.jpg
#   inflating: images/25533.jpg
#   inflating: images/12123.jpg
#   inflating: images/23110.jpg
#   inflating: images/32637.jpg
#   inflating: images/15046.jpg
#   inflating: images/16050.jpg
#   inflating: images/1811.jpg
#   inflating: images/1201.jpg
#   inflating: images/12603.jpg
#   inflating: images/34500.jpg
#   inflating: images/18233.jpg
#   inflating: images/30769.jpg
#   inflating: images/13980.jpg
#   inflating: images/2150.jpg
#   inflating: images/12888.jpg
#   inflating: images/24017.jpg
#   inflating: images/10062.jpg
#   inflating: images/561.jpg
#   inflating: images/18968.jpg
#   inflating: images/34062.jpg
#   inflating: images/3396.jpg
#   inflating: images/30440.jpg
#   inflating: images/22532.jpg
#   inflating: images/28875.jpg
#   inflating: images/24954.jpg
#   inflating: images/33302.jpg
#   inflating: images/6002.jpg
#   inflating: images/9100.jpg
#   inflating: images/33169.jpg
#   inflating: images/14169.jpg
#   inflating: images/969.jpg
#   inflating: images/2392.jpg
#   inflating: images/3933.jpg
#   inflating: images/11207.jpg
#   inflating: images/23506.jpg
#   inflating: images/10625.jpg
#   inflating: images/11435.jpg
#   inflating: images/19726.jpg
#   inflating: images/12903.jpg
#   inflating: images/9867.jpg
#   inflating: images/28074.jpg
#   inflating: images/21418.jpg
#   inflating: images/11773.jpg
#   inflating: images/34972.jpg
#   inflating: images/7105.jpg
#   inflating: images/16267.jpg
#   inflating: images/10236.jpg
#   inflating: images/30799.jpg
#   inflating: images/2631.jpg
#   inflating: images/10761.jpg
#   inflating: images/16826.jpg
#   inflating: images/700.jpg
#   inflating: images/14477.jpg
#   inflating: images/6033.jpg
#   inflating: images/6088.jpg
#   inflating: images/18698.jpg
#   inflating: images/34632.jpg
#   inflating: images/31389.jpg
#   inflating: images/4779.jpg
#   inflating: images/7426.jpg
#   inflating: images/14322.jpg
#   inflating: images/26963.jpg
#   inflating: images/34330.jpg
#   inflating: images/13262.jpg
#   inflating: images/21915.jpg
#   inflating: images/19554.jpg
#   inflating: images/30122.jpg
#   inflating: images/7626.jpg
#   inflating: images/12839.jpg
#   inflating: images/23934.jpg
#   inflating: images/5518.jpg
#   inflating: images/25562.jpg
#   inflating: images/11558.jpg
#   inflating: images/14126.jpg
#   inflating: images/24175.jpg
#   inflating: images/34908.jpg
#   inflating: images/17935.jpg
#   inflating: images/17885.jpg
#   inflating: images/30505.jpg
#   inflating: images/16402.jpg
#   inflating: images/380.jpg
#   inflating: images/34690.jpg
#   inflating: images/28465.jpg
#   inflating: images/14414.jpg
#   inflating: images/31024.jpg
#   inflating: images/16991.jpg
#   inflating: images/20031.jpg
#   inflating: images/29354.jpg
#   inflating: images/3497.jpg
#   inflating: images/3245.jpg
#   inflating: images/17736.jpg
#   inflating: images/33246.jpg
#   inflating: images/31433.jpg
#   inflating: images/35745.jpg
#   inflating: images/5152.jpg
#   inflating: images/4079.jpg
#   inflating: images/26822.jpg
#   inflating: images/28864.jpg
#   inflating: images/32028.jpg
#   inflating: images/14747.jpg
#   inflating: images/28316.jpg
#   inflating: images/18340.jpg
#   inflating: images/2526.jpg
#   inflating: images/23605.jpg
#   inflating: images/35696.jpg
#   inflating: images/31263.jpg
#   inflating: images/4138.jpg
#   inflating: images/4764.jpg
#   inflating: images/23536.jpg
#   inflating: images/1933.jpg
#   inflating: images/14021.jpg
#   inflating: images/12571.jpg
#   inflating: images/32979.jpg
#   inflating: images/4595.jpg
#   inflating: images/26854.jpg
#   inflating: images/22794.jpg
#   inflating: images/18966.jpg
#   inflating: images/15527.jpg
#   inflating: images/34298.jpg
#   inflating: images/35944.jpg
#   inflating: images/6989.jpg
#   inflating: images/27227.jpg
#   inflating: images/15165.jpg
#   inflating: images/25246.jpg
#   inflating: images/26589.jpg
#   inflating: images/25672.jpg
#   inflating: images/26090.jpg
#   inflating: images/35893.jpg
#   inflating: images/4322.jpg
#   inflating: images/1559.jpg
#   inflating: images/32137.jpg
#   inflating: images/35748.jpg
#   inflating: images/13489.jpg
#   inflating: images/17263.jpg
#   inflating: images/1390.jpg
#   inflating: images/8873.jpg
#   inflating: images/12034.jpg
#   inflating: images/30164.jpg
#   inflating: images/13052.jpg
#   inflating: images/11560.jpg
#   inflating: images/23436.jpg
#   inflating: images/12868.jpg
#   inflating: images/13473.jpg
#   inflating: images/10438.jpg
#   inflating: images/33567.jpg
#   inflating: images/32984.jpg
#   inflating: images/10076.jpg
#   inflating: images/24886.jpg
#   inflating: images/32989.jpg
#   inflating: images/21814.jpg
#   inflating: images/26142.jpg
#   inflating: images/31359.jpg
#   inflating: images/23220.jpg
#   inflating: images/590.jpg
#   inflating: images/7879.jpg
#   inflating: images/21303.jpg
#   inflating: images/28190.jpg
#   inflating: images/35231.jpg
#   inflating: images/4234.jpg
#   inflating: images/16430.jpg
#   inflating: images/22067.jpg
#   inflating: images/31636.jpg
#   inflating: images/10788.jpg
#   inflating: images/33282.jpg
#   inflating: images/6064.jpg
#   inflating: images/21404.jpg
#   inflating: images/727.jpg
#   inflating: images/22030.jpg
#   inflating: images/9619.jpg
#   inflating: images/1913.jpg
#   inflating: images/5225.jpg
#   inflating: images/11198.jpg
#   inflating: images/26723.jpg
#   inflating: images/3256.jpg
#   inflating: images/21172.jpg
#   inflating: images/18833.jpg
#   inflating: images/22987.jpg
#   inflating: images/35917.jpg
#   inflating: images/6696.jpg
#   inflating: images/24322.jpg
#   inflating: images/3140.jpg
#   inflating: images/12365.jpg
#   inflating: images/12419.jpg
#   inflating: images/18653.jpg
#   inflating: images/21695.jpg
#   inflating: images/18296.jpg
#   inflating: images/10119.jpg
#   inflating: images/7687.jpg
#   inflating: images/956.jpg
#   inflating: images/15013.jpg
#   inflating: images/10097.jpg
#   inflating: images/15207.jpg
#   inflating: images/28096.jpg
#   inflating: images/78.jpg
#   inflating: images/22631.jpg
#   inflating: images/28413.jpg
#   inflating: images/19923.jpg
#   inflating: images/18362.jpg
#   inflating: images/18369.jpg
#   inflating: images/26423.jpg
#   inflating: images/3813.jpg
#   inflating: images/34815.jpg
#   inflating: images/18636.jpg
#   inflating: images/10159.jpg
#   inflating: images/6382.jpg
#   inflating: images/28264.jpg
#   inflating: images/6386.jpg
#   inflating: images/26220.jpg
#   inflating: images/36129.jpg
#   inflating: images/2068.jpg
#   inflating: images/36052.jpg
#   inflating: images/18287.jpg
#   inflating: images/21619.jpg
#   inflating: images/15260.jpg
#   inflating: images/25904.jpg
#   inflating: images/7071.jpg
#   inflating: images/30916.jpg
#   inflating: images/27075.jpg
#   inflating: images/31591.jpg
#   inflating: images/20583.jpg
#   inflating: images/7267.jpg
#   inflating: images/16852.jpg
#   inflating: images/16367.jpg
#   inflating: images/32004.jpg
#   inflating: images/21134.jpg
#   inflating: images/7080.jpg
#   inflating: images/4361.jpg
#   inflating: images/25664.jpg
#   inflating: images/1345.jpg
#   inflating: images/19857.jpg
#   inflating: images/27931.jpg
#   inflating: images/850.jpg
#   inflating: images/30981.jpg
#   inflating: images/11282.jpg
#   inflating: images/16871.jpg
#   inflating: images/16197.jpg
#   inflating: images/14922.jpg
#   inflating: images/8611.jpg
#   inflating: images/28729.jpg
#   inflating: images/14352.jpg
#   inflating: images/19656.jpg
#   inflating: images/16508.jpg
#   inflating: images/3495.jpg
#   inflating: images/5055.jpg
#   inflating: images/12214.jpg
#   inflating: images/14807.jpg
#   inflating: images/34795.jpg
#   inflating: images/3584.jpg
#   inflating: images/14536.jpg
#   inflating: images/20820.jpg
#   inflating: images/10340.jpg
#   inflating: images/25552.jpg
#   inflating: images/14723.jpg
#   inflating: images/601.jpg
#   inflating: images/34013.jpg
#   inflating: images/3968.jpg
#   inflating: images/23703.jpg
#   inflating: images/20118.jpg
#   inflating: images/20391.jpg
#   inflating: images/22584.jpg
#   inflating: images/20856.jpg
#   inflating: images/25436.jpg
#   inflating: images/34435.jpg
#   inflating: images/25323.jpg
#   inflating: images/31382.jpg
#   inflating: images/5712.jpg
#   inflating: images/33697.jpg
#   inflating: images/20532.jpg
#   inflating: images/27784.jpg
#   inflating: images/28119.jpg
#   inflating: images/26782.jpg
#   inflating: images/23898.jpg
#   inflating: images/13166.jpg
#   inflating: images/1977.jpg
#   inflating: images/23621.jpg
#   inflating: images/27932.jpg
#   inflating: images/19175.jpg
#   inflating: images/18892.jpg
#   inflating: images/31810.jpg
#   inflating: images/24401.jpg
#   inflating: images/2916.jpg
#   inflating: images/19736.jpg
#   inflating: images/13651.jpg
#   inflating: images/10182.jpg
#   inflating: images/13757.jpg
#   inflating: images/17420.jpg
#   inflating: images/16573.jpg
#   inflating: images/5464.jpg
#   inflating: images/15348.jpg
#   inflating: images/20430.jpg
#   inflating: images/2145.jpg
#   inflating: images/3018.jpg
#   inflating: images/1773.jpg
#   inflating: images/24140.jpg
#   inflating: images/42.jpg
#   inflating: images/33146.jpg
#   inflating: images/25282.jpg
#   inflating: images/30230.jpg
#   inflating: images/3402.jpg
#   inflating: images/31887.jpg
#   inflating: images/21332.jpg
#   inflating: images/23924.jpg
#   inflating: images/26717.jpg
#   inflating: images/7668.jpg
#   inflating: images/26139.jpg
#   inflating: images/25942.jpg
#   inflating: images/33749.jpg
#   inflating: images/11946.jpg
#   inflating: images/34766.jpg
#   inflating: images/24707.jpg
#   inflating: images/4862.jpg
#   inflating: images/22811.jpg
#   inflating: images/5718.jpg
#   inflating: images/13402.jpg
#   inflating: images/8569.jpg
#   inflating: images/14003.jpg
#   inflating: images/25444.jpg
#   inflating: images/15887.jpg
#   inflating: images/26752.jpg
#   inflating: images/26251.jpg
#   inflating: images/21409.jpg
#   inflating: images/20598.jpg
#   inflating: images/29096.jpg
#   inflating: images/9358.jpg
#   inflating: images/35682.jpg
#   inflating: images/3970.jpg
#   inflating: images/30714.jpg
#   inflating: images/5328.jpg
#   inflating: images/29940.jpg
#   inflating: images/22805.jpg
#   inflating: images/35809.jpg
#   inflating: images/24448.jpg
#   inflating: images/13761.jpg
#   inflating: images/8804.jpg
#   inflating: images/11019.jpg
#   inflating: images/23951.jpg
#   inflating: images/319.jpg
#   inflating: images/36556.jpg
#   inflating: images/2379.jpg
#   inflating: images/12966.jpg
#   inflating: images/3665.jpg
#   inflating: images/31325.jpg
#   inflating: images/21609.jpg
#   inflating: images/23123.jpg
#   inflating: images/23256.jpg
#   inflating: images/30391.jpg
#   inflating: images/13674.jpg
#   inflating: images/7467.jpg
#   inflating: images/30944.jpg
#   inflating: images/11620.jpg
#   inflating: images/4438.jpg
#   inflating: images/29208.jpg
#   inflating: images/6454.jpg
#   inflating: images/28780.jpg
#   inflating: images/2348.jpg
#   inflating: images/31990.jpg
#   inflating: images/7757.jpg
#   inflating: images/15641.jpg
#   inflating: images/34267.jpg
#   inflating: images/20122.jpg
#   inflating: images/3761.jpg
#   inflating: images/32818.jpg
#   inflating: images/36030.jpg
#   inflating: images/32827.jpg
#   inflating: images/18344.jpg
#   inflating: images/27287.jpg
#   inflating: images/34679.jpg
#   inflating: images/12254.jpg
#   inflating: images/7556.jpg
#   inflating: images/26255.jpg
#   inflating: images/16414.jpg
#   inflating: images/19763.jpg
#   inflating: images/1755.jpg
#   inflating: images/30186.jpg
#   inflating: images/36219.jpg
#   inflating: images/21089.jpg
#   inflating: images/8660.jpg
#   inflating: images/11811.jpg
#   inflating: images/17822.jpg
#   inflating: images/27133.jpg
#   inflating: images/6578.jpg
#   inflating: images/33633.jpg
#   inflating: images/26110.jpg
#   inflating: images/34044.jpg
#   inflating: images/5185.jpg
#   inflating: images/30182.jpg
#   inflating: images/19337.jpg
#   inflating: images/18777.jpg
#   inflating: images/21956.jpg
#   inflating: images/8507.jpg
#   inflating: images/15799.jpg
#   inflating: images/14080.jpg
#   inflating: images/21108.jpg
#   inflating: images/1488.jpg
#   inflating: images/3940.jpg
#   inflating: images/10284.jpg
#   inflating: images/3282.jpg
#   inflating: images/29839.jpg
#   inflating: images/16257.jpg
#   inflating: images/28129.jpg
#   inflating: images/1605.jpg
#   inflating: images/30260.jpg
#   inflating: images/20747.jpg
#   inflating: images/8290.jpg
#   inflating: images/23984.jpg
#   inflating: images/31318.jpg
#   inflating: images/18067.jpg
#   inflating: images/12516.jpg
#   inflating: images/21053.jpg
#   inflating: images/622.jpg
#   inflating: images/13024.jpg
#   inflating: images/20722.jpg
#   inflating: images/21200.jpg
#   inflating: images/23483.jpg
#   inflating: images/35039.jpg
#   inflating: images/21491.jpg
#   inflating: images/24084.jpg
#   inflating: images/28051.jpg
#   inflating: images/14019.jpg
#   inflating: images/21288.jpg
#   inflating: images/7675.jpg
#   inflating: images/30333.jpg
#   inflating: images/17512.jpg
#   inflating: images/4906.jpg
#   inflating: images/6642.jpg
#   inflating: images/24760.jpg
#   inflating: images/32405.jpg
#   inflating: images/25457.jpg
#   inflating: images/15897.jpg
#   inflating: images/8542.jpg
#   inflating: images/21414.jpg
#   inflating: images/14204.jpg
#   inflating: images/20599.jpg
#   inflating: images/6808.jpg
#   inflating: images/31884.jpg
#   inflating: images/27575.jpg
#   inflating: images/33311.jpg
#   inflating: images/27798.jpg
#   inflating: images/1563.jpg
#   inflating: images/849.jpg
#   inflating: images/22525.jpg
#   inflating: images/18301.jpg
#   inflating: images/22739.jpg
#   inflating: images/32101.jpg
#   inflating: images/6333.jpg
#   inflating: images/16869.jpg
#   inflating: images/26575.jpg
#   inflating: images/725.jpg
#   inflating: images/23542.jpg
#   inflating: images/22694.jpg
#   inflating: images/11456.jpg
#   inflating: images/3995.jpg
#   inflating: images/35065.jpg
#   inflating: images/368.jpg
#   inflating: images/18521.jpg
#   inflating: images/10088.jpg
#   inflating: images/8478.jpg
#   inflating: images/11973.jpg
#   inflating: images/16609.jpg
#   inflating: images/26164.jpg
#   inflating: images/32471.jpg
#   inflating: images/17233.jpg
#   inflating: images/4536.jpg
#   inflating: images/15567.jpg
#   inflating: images/28745.jpg
#   inflating: images/10160.jpg
#   inflating: images/13021.jpg
#   inflating: images/2911.jpg
#   inflating: images/3127.jpg
#   inflating: images/5624.jpg
#   inflating: images/2769.jpg
#   inflating: images/28531.jpg
#   inflating: images/12024.jpg
#   inflating: images/27337.jpg
#   inflating: images/22208.jpg
#   inflating: images/17286.jpg
#   inflating: images/17700.jpg
#   inflating: images/22244.jpg
#   inflating: images/18875.jpg
#   inflating: images/26679.jpg
#   inflating: images/4070.jpg
#   inflating: images/937.jpg
#   inflating: images/22379.jpg
#   inflating: images/10401.jpg
#   inflating: images/2017.jpg
#   inflating: images/4285.jpg
#   inflating: images/5277.jpg
#   inflating: images/22907.jpg
#   inflating: images/19486.jpg
#   inflating: images/10836.jpg
#   inflating: images/9875.jpg
#   inflating: images/8444.jpg
#   inflating: images/31013.jpg
#   inflating: images/26830.jpg
#   inflating: images/5647.jpg
#   inflating: images/29104.jpg
#   inflating: images/18721.jpg
#   inflating: images/36131.jpg
#   inflating: images/5939.jpg
#   inflating: images/30360.jpg
#   inflating: images/48.jpg
#   inflating: images/16566.jpg
#   inflating: images/2386.jpg
#   inflating: images/22193.jpg
#   inflating: images/29819.jpg
#   inflating: images/28028.jpg
#   inflating: images/16088.jpg
#   inflating: images/25643.jpg
#   inflating: images/9373.jpg
#   inflating: images/35027.jpg
#   inflating: images/4630.jpg
#   inflating: images/29996.jpg
#   inflating: images/36427.jpg
#   inflating: images/3947.jpg
#   inflating: images/27120.jpg
#   inflating: images/28318.jpg
#   inflating: images/30879.jpg
#   inflating: images/8884.jpg
#   inflating: images/1502.jpg
#   inflating: images/34497.jpg
#   inflating: images/24320.jpg
#   inflating: images/30616.jpg
#   inflating: images/12152.jpg
#   inflating: images/23050.jpg
#   inflating: images/20028.jpg
#   inflating: images/29375.jpg
#   inflating: images/5406.jpg
#   inflating: images/36379.jpg
#   inflating: images/10270.jpg
#   inflating: images/36651.jpg
#   inflating: images/26205.jpg
#   inflating: images/17213.jpg
#   inflating: images/870.jpg
#   inflating: images/30069.jpg
#   inflating: images/35167.jpg
#   inflating: images/12599.jpg
#   inflating: images/24560.jpg
#   inflating: images/4078.jpg
#   inflating: images/29127.jpg
#   inflating: images/35672.jpg
#   inflating: images/4546.jpg
#   inflating: images/29413.jpg
#   inflating: images/33694.jpg
#   inflating: images/33359.jpg
#   inflating: images/16227.jpg
#   inflating: images/21526.jpg
#   inflating: images/23849.jpg
#   inflating: images/20764.jpg
#   inflating: images/33171.jpg
#   inflating: images/12869.jpg
#   inflating: images/13361.jpg
#   inflating: images/22624.jpg
#   inflating: images/14460.jpg
#   inflating: images/23589.jpg
#   inflating: images/3016.jpg
#   inflating: images/26951.jpg
#   inflating: images/28451.jpg
#   inflating: images/26505.jpg
#   inflating: images/17915.jpg
#   inflating: images/35933.jpg
#   inflating: images/34162.jpg
#   inflating: images/13567.jpg
#   inflating: images/3035.jpg
#   inflating: images/35732.jpg
#   inflating: images/25516.jpg
#   inflating: images/11777.jpg
#   inflating: images/11548.jpg
#   inflating: images/8720.jpg
#   inflating: images/6146.jpg
#   inflating: images/7768.jpg
#   inflating: images/30097.jpg
#   inflating: images/30871.jpg
#   inflating: images/11600.jpg
#   inflating: images/29615.jpg
#   inflating: images/33532.jpg
#   inflating: images/22467.jpg
#   inflating: images/825.jpg
#   inflating: images/5753.jpg
#   inflating: images/12098.jpg
#   inflating: images/18299.jpg
#   inflating: images/34768.jpg
#   inflating: images/1344.jpg
#   inflating: images/21322.jpg
#   inflating: images/9691.jpg
#   inflating: images/3198.jpg
#   inflating: images/4253.jpg
#   inflating: images/7055.jpg
#   inflating: images/34667.jpg
#   inflating: images/20981.jpg
#   inflating: images/10396.jpg
#   inflating: images/13456.jpg
#   inflating: images/11768.jpg
#   inflating: images/32525.jpg
#   inflating: images/15881.jpg
#   inflating: images/15355.jpg
#   inflating: images/1355.jpg
#   inflating: images/7670.jpg
#   inflating: images/3784.jpg
#   inflating: images/24127.jpg
#   inflating: images/30948.jpg
#   inflating: images/35622.jpg
#   inflating: images/32689.jpg
#   inflating: images/7842.jpg
#   inflating: images/26655.jpg
#   inflating: images/8318.jpg
#   inflating: images/24461.jpg
#   inflating: images/33718.jpg
#   inflating: images/35733.jpg
#   inflating: images/21043.jpg
#   inflating: images/23223.jpg
#   inflating: images/33484.jpg
#   inflating: images/9688.jpg
#   inflating: images/30986.jpg
#   inflating: images/31527.jpg
#   inflating: images/32202.jpg
#   inflating: images/31573.jpg
#   inflating: images/2538.jpg
#   inflating: images/28445.jpg
#   inflating: images/8275.jpg
#   inflating: images/16004.jpg
#   inflating: images/32654.jpg
#   inflating: images/24051.jpg
#   inflating: images/20461.jpg
#   inflating: images/28259.jpg
#   inflating: images/28734.jpg
#   inflating: images/31787.jpg
#   inflating: images/28955.jpg
#   inflating: images/18205.jpg
#   inflating: images/17702.jpg
#   inflating: images/5634.jpg
#   inflating: images/15282.jpg
#   inflating: images/23222.jpg
#   inflating: images/16694.jpg
#   inflating: images/12341.jpg
#   inflating: images/12691.jpg
#   inflating: images/2776.jpg
#   inflating: images/17433.jpg
#   inflating: images/26580.jpg
#   inflating: images/35559.jpg
#   inflating: images/9189.jpg
#   inflating: images/15362.jpg
#   inflating: images/24345.jpg
#   inflating: images/2800.jpg
#   inflating: images/11471.jpg
#   inflating: images/7232.jpg
#   inflating: images/22595.jpg
#   inflating: images/15936.jpg
#   inflating: images/17649.jpg
#   inflating: images/36386.jpg
#   inflating: images/3568.jpg
#   inflating: images/35422.jpg
#   inflating: images/3841.jpg
#   inflating: images/7692.jpg
#   inflating: images/28909.jpg
#   inflating: images/11128.jpg
#   inflating: images/31601.jpg
#   inflating: images/36081.jpg
#   inflating: images/29031.jpg
#   inflating: images/27105.jpg
#   inflating: images/36123.jpg
#   inflating: images/24387.jpg
#   inflating: images/32351.jpg
#   inflating: images/10331.jpg
#   inflating: images/24065.jpg
#   inflating: images/8962.jpg
#   inflating: images/4860.jpg
#   inflating: images/23563.jpg
#   inflating: images/18467.jpg
#   inflating: images/12894.jpg
#   inflating: images/1803.jpg
#   inflating: images/4095.jpg
#   inflating: images/33452.jpg
#   inflating: images/4588.jpg
#   inflating: images/6523.jpg
#   inflating: images/25305.jpg
#   inflating: images/13521.jpg
#   inflating: images/8506.jpg
#   inflating: images/6609.jpg
#   inflating: images/6687.jpg
#   inflating: images/33427.jpg
#   inflating: images/30576.jpg
#   inflating: images/6474.jpg
#   inflating: images/9587.jpg
#   inflating: images/20445.jpg
#   inflating: images/3953.jpg
#   inflating: images/29287.jpg
#   inflating: images/29836.jpg
#   inflating: images/6154.jpg
#   inflating: images/4431.jpg
#   inflating: images/24439.jpg
#   inflating: images/6235.jpg
#   inflating: images/14329.jpg
#   inflating: images/7282.jpg
#   inflating: images/111.jpg
#   inflating: images/15293.jpg
#   inflating: images/21082.jpg
#   inflating: images/7744.jpg
#   inflating: images/28425.jpg
#   inflating: images/33475.jpg
#   inflating: images/6637.jpg
#   inflating: images/3293.jpg
#   inflating: images/16490.jpg
#   inflating: images/27875.jpg
#   inflating: images/9649.jpg
#   inflating: images/5318.jpg
#   inflating: images/25482.jpg
#   inflating: images/783.jpg
#   inflating: images/27525.jpg
#   inflating: images/13963.jpg
#   inflating: images/30953.jpg
#   inflating: images/5344.jpg
#   inflating: images/17812.jpg
#   inflating: images/2271.jpg
# ...
#   inflating: images/25054.jpg
#   inflating: images/28705.jpg
#   inflating: images/28764.jpg
#   inflating: images/5953.jpg
#   inflating: images/12376.jpg
#   inflating: images/26568.jpg
#   inflating: images/7148.jpg
#   inflating: images/14411.jpg
#   inflating: images/16055.jpg
#   inflating: images/27121.jpg
#   inflating: images/5986.jpg
#   inflating: images/4562.jpg
#   inflating: images/31551.jpg
#   inflating: images/14731.jpg
#   inflating: images/15763.jpg
#   inflating: images/35929.jpg
#   inflating: images/3752.jpg
#   inflating: images/5782.jpg
#   inflating: images/21036.jpg
#   inflating: images/25149.jpg
#   inflating: images/19793.jpg
#   inflating: images/25335.jpg
#   inflating: images/15581.jpg
#   inflating: images/28261.jpg
#   inflating: images/4073.jpg
#   inflating: images/18915.jpg
#   inflating: images/14560.jpg
#   inflating: images/18675.jpg
#   inflating: images/14821.jpg
#   inflating: images/14474.jpg
#   inflating: images/27138.jpg
#   inflating: images/5363.jpg
#   inflating: images/30390.jpg
#   inflating: images/5339.jpg
#   inflating: images/23689.jpg
#   inflating: images/567.jpg
#   inflating: images/12796.jpg
#   inflating: images/11986.jpg
#   inflating: images/14415.jpg
#   inflating: images/15570.jpg
#   inflating: images/15806.jpg
#   inflating: images/18754.jpg
#   inflating: images/20542.jpg
#   inflating: images/10310.jpg
#   inflating: images/5993.jpg
#   inflating: images/19396.jpg
#   inflating: images/23139.jpg
#   inflating: images/33285.jpg
#   inflating: images/12756.jpg
#   inflating: images/11660.jpg
#   inflating: images/14892.jpg
#   inflating: images/16522.jpg
#   inflating: images/24699.jpg
#   inflating: images/9521.jpg
#   inflating: images/4859.jpg
#   inflating: images/12564.jpg
#   inflating: images/28020.jpg
#   inflating: images/18475.jpg
#   inflating: images/18908.jpg
#   inflating: images/27245.jpg
#   inflating: images/14490.jpg
#   inflating: images/13789.jpg
#   inflating: images/25147.jpg
#   inflating: images/21268.jpg
#   inflating: images/31328.jpg
#   inflating: images/35282.jpg
#   inflating: images/10902.jpg
#   inflating: images/2287.jpg
#   inflating: images/32098.jpg
#   inflating: images/36575.jpg
#   inflating: images/34205.jpg
#   inflating: images/13960.jpg
#   inflating: images/20223.jpg
#   inflating: images/10255.jpg
#   inflating: images/8357.jpg
#   inflating: images/25540.jpg
#   inflating: images/3960.jpg
#   inflating: images/22656.jpg
#   inflating: images/23358.jpg
#   inflating: images/36568.jpg
#   inflating: images/29945.jpg
#   inflating: images/13033.jpg
#   inflating: images/17723.jpg
#   inflating: images/1983.jpg
#   inflating: images/20268.jpg
#   inflating: images/10976.jpg
#   inflating: images/33704.jpg
#   inflating: images/1852.jpg
#   inflating: images/34650.jpg
#   inflating: images/28207.jpg
#   inflating: images/36260.jpg
#   inflating: images/25489.jpg
#   inflating: images/27386.jpg
#   inflating: images/30570.jpg
#   inflating: images/16064.jpg
#   inflating: images/8968.jpg
#   inflating: images/4943.jpg
#   inflating: images/26648.jpg
#   inflating: images/36007.jpg
#   inflating: images/10480.jpg
#   inflating: images/20506.jpg
#   inflating: images/18906.jpg
#   inflating: images/3221.jpg
#   inflating: images/11160.jpg
#   inflating: images/6960.jpg
#   inflating: images/36216.jpg
#   inflating: images/23004.jpg
#   inflating: images/32268.jpg
#   inflating: images/13655.jpg
#   inflating: images/13540.jpg
#   inflating: images/19571.jpg
#   inflating: images/29915.jpg
#   inflating: images/19178.jpg
#   inflating: images/36418.jpg
#   inflating: images/22381.jpg
#   inflating: images/17312.jpg
#   inflating: images/24733.jpg
#   inflating: images/20410.jpg
#   inflating: images/20857.jpg
#   inflating: images/291.jpg
#   inflating: images/17946.jpg
#   inflating: images/10953.jpg
#   inflating: images/28970.jpg
#   inflating: images/15213.jpg
#   inflating: images/1687.jpg
#   inflating: images/373.jpg
#   inflating: images/483.jpg
#   inflating: images/4736.jpg
#   inflating: images/23846.jpg
#   inflating: images/2519.jpg
#   inflating: images/17936.jpg
#   inflating: images/6985.jpg
#   inflating: images/24526.jpg
#   inflating: images/32997.jpg
#   inflating: images/26407.jpg
#   inflating: images/23175.jpg
#   inflating: images/13216.jpg
#   inflating: images/36175.jpg
#   inflating: images/28722.jpg
#   inflating: images/32448.jpg
#   inflating: images/31857.jpg
#   inflating: images/19670.jpg
#   inflating: images/3729.jpg
#   inflating: images/12167.jpg
#   inflating: images/2680.jpg
#   inflating: images/15612.jpg
#   inflating: images/2335.jpg
#   inflating: images/18823.jpg
#   inflating: images/23613.jpg
#   inflating: images/25532.jpg
#   inflating: images/33885.jpg
#   inflating: images/18850.jpg
#   inflating: images/8261.jpg
#   inflating: images/30954.jpg
#   inflating: images/15961.jpg
#   inflating: images/16432.jpg
#   inflating: images/4776.jpg
#   inflating: images/23785.jpg
#   inflating: images/21933.jpg
#   inflating: images/16497.jpg
#   inflating: images/24006.jpg
#   inflating: images/5895.jpg
#   inflating: images/31185.jpg
#   inflating: images/1276.jpg
#   inflating: images/890.jpg
#   inflating: images/2506.jpg
#   inflating: images/9084.jpg
#   inflating: images/2518.jpg
#   inflating: images/17267.jpg
#   inflating: images/3786.jpg
#   inflating: images/22567.jpg
#   inflating: images/1771.jpg
#   inflating: images/25133.jpg
#   inflating: images/10759.jpg
#   inflating: images/34280.jpg
#   inflating: images/34206.jpg
#   inflating: images/32953.jpg
#   inflating: images/6439.jpg
#   inflating: images/12931.jpg
#   inflating: images/9572.jpg
#   inflating: images/16426.jpg
#   inflating: images/22659.jpg
#   inflating: images/11964.jpg
#   inflating: images/2256.jpg
#   inflating: images/28995.jpg
#   inflating: images/11123.jpg
#   inflating: images/29090.jpg
#   inflating: images/28631.jpg
#   inflating: images/13748.jpg
#   inflating: images/12930.jpg
#   inflating: images/20633.jpg
#   inflating: images/13929.jpg
#   inflating: images/22251.jpg
#   inflating: images/1821.jpg
#   inflating: images/30909.jpg
#   inflating: images/26645.jpg
#   inflating: images/11256.jpg
#   inflating: images/1659.jpg
#   inflating: images/7324.jpg
#   inflating: images/1774.jpg
#   inflating: images/33542.jpg
#   inflating: images/25703.jpg
#   inflating: images/5802.jpg
#   inflating: images/36577.jpg
#   inflating: images/34842.jpg
#   inflating: images/26964.jpg
#   inflating: images/33049.jpg
#   inflating: images/29064.jpg
#   inflating: images/26999.jpg
#   inflating: images/27977.jpg
#   inflating: images/20345.jpg
#   inflating: images/23722.jpg
#   inflating: images/23847.jpg
#   inflating: images/14729.jpg
#   inflating: images/8126.jpg
#   inflating: images/19139.jpg
#   inflating: images/32495.jpg
#   inflating: images/28534.jpg
#   inflating: images/19249.jpg
#   inflating: images/2358.jpg
#   inflating: images/27496.jpg
#   inflating: images/24508.jpg
#   inflating: images/31680.jpg
#   inflating: images/11242.jpg
#   inflating: images/14316.jpg
#   inflating: images/13343.jpg
#   inflating: images/36174.jpg
#   inflating: images/3739.jpg
#   inflating: images/21927.jpg
#   inflating: images/1723.jpg
#   inflating: images/26652.jpg
#   inflating: images/34117.jpg
#   inflating: images/36614.jpg
#   inflating: images/31196.jpg
#   inflating: images/25080.jpg
#   inflating: images/8791.jpg
#   inflating: images/29817.jpg
#   inflating: images/34833.jpg
#   inflating: images/2783.jpg
#   inflating: images/15241.jpg
#   inflating: images/26815.jpg
#   inflating: images/11564.jpg
#   inflating: images/18772.jpg
#   inflating: images/8339.jpg
#   inflating: images/3767.jpg
#   inflating: images/4123.jpg
#   inflating: images/11779.jpg
#   inflating: images/23525.jpg
#   inflating: images/32330.jpg
#   inflating: images/10888.jpg
#   inflating: images/8233.jpg
#   inflating: images/2171.jpg
#   inflating: images/25030.jpg
#   inflating: images/18199.jpg
#   inflating: images/15062.jpg
#   inflating: images/25052.jpg
#   inflating: images/32349.jpg
#   inflating: images/28224.jpg
#   inflating: images/30047.jpg
#   inflating: images/18470.jpg
#   inflating: images/14265.jpg
#   inflating: images/29435.jpg
#   inflating: images/2590.jpg
#   inflating: images/29944.jpg
#   inflating: images/28775.jpg
#   inflating: images/1136.jpg
#   inflating: images/31457.jpg
#   inflating: images/13846.jpg
#   inflating: images/18934.jpg
#   inflating: images/31141.jpg
#   inflating: images/26403.jpg
#   inflating: images/3247.jpg
#   inflating: images/15779.jpg
#   inflating: images/25723.jpg
#   inflating: images/2853.jpg
#   inflating: images/8700.jpg
#   inflating: images/35295.jpg
#   inflating: images/10381.jpg
#   inflating: images/35970.jpg
#   inflating: images/3614.jpg
#   inflating: images/5313.jpg
#   inflating: images/31449.jpg
#   inflating: images/27094.jpg
#   inflating: images/3417.jpg
#   inflating: images/11100.jpg
#   inflating: images/3229.jpg
#   inflating: images/7869.jpg
#   inflating: images/27576.jpg
#   inflating: images/277.jpg
#   inflating: images/6280.jpg
#   inflating: images/32627.jpg
#   inflating: images/6019.jpg
#   inflating: images/31106.jpg
#   inflating: images/3120.jpg
#   inflating: images/17814.jpg
#   inflating: images/4385.jpg
#   inflating: images/23761.jpg
#   inflating: images/10525.jpg
#   inflating: images/2729.jpg
#   inflating: images/25788.jpg
#   inflating: images/226.jpg
#   inflating: images/7060.jpg
#   inflating: images/14923.jpg
#   inflating: images/36333.jpg
#   inflating: images/18502.jpg
#   inflating: images/34126.jpg
#   inflating: images/32885.jpg
#   inflating: images/4384.jpg
#   inflating: images/3608.jpg
#   inflating: images/28055.jpg
#   inflating: images/1486.jpg
#   inflating: images/19468.jpg
#   inflating: images/2649.jpg
#   inflating: images/34885.jpg
#   inflating: images/12913.jpg
#   inflating: images/6226.jpg
#   inflating: images/16094.jpg
#   inflating: images/6397.jpg
#   inflating: images/240.jpg
#   inflating: images/29718.jpg
#   inflating: images/23170.jpg
#   inflating: images/11990.jpg
#   inflating: images/36259.jpg
#   inflating: images/20144.jpg
#   inflating: images/17850.jpg
#   inflating: images/11491.jpg
#   inflating: images/25065.jpg
#   inflating: images/2459.jpg
#   inflating: images/15871.jpg
#   inflating: images/18314.jpg
#   inflating: images/31746.jpg
#   inflating: images/7831.jpg
#   inflating: images/18227.jpg
#   inflating: images/36654.jpg
#   inflating: images/1267.jpg
#   inflating: images/5846.jpg
#   inflating: images/28333.jpg
#   inflating: images/22182.jpg
#   inflating: images/32921.jpg
#   inflating: images/20064.jpg
#   inflating: images/20071.jpg
#   inflating: images/22520.jpg
#   inflating: images/3175.jpg
#   inflating: images/2367.jpg
#   inflating: images/28968.jpg
#   inflating: images/4222.jpg
#   inflating: images/35150.jpg
#   inflating: images/17412.jpg
#   inflating: images/17392.jpg
#   inflating: images/31224.jpg
#   inflating: images/30540.jpg
#   inflating: images/23440.jpg
#   inflating: images/3630.jpg
#   inflating: images/140.jpg
#   inflating: images/1819.jpg
#   inflating: images/13281.jpg
#   inflating: images/7952.jpg
#   inflating: images/20244.jpg
#   inflating: images/21378.jpg
#   inflating: images/11488.jpg
#   inflating: images/6237.jpg
#   inflating: images/22165.jpg
#   inflating: images/31640.jpg
#   inflating: images/28984.jpg
#   inflating: images/22487.jpg
#   inflating: images/58.jpg
#   inflating: images/23868.jpg
#   inflating: images/18242.jpg
#   inflating: images/23862.jpg
#   inflating: images/18860.jpg
#   inflating: images/21702.jpg
#   inflating: images/6112.jpg
#   inflating: images/24454.jpg
#   inflating: images/22699.jpg
#   inflating: images/10853.jpg
#   inflating: images/754.jpg
#   inflating: images/33566.jpg
#   inflating: images/28331.jpg
#   inflating: images/7787.jpg
#   inflating: images/9701.jpg
#   inflating: images/11958.jpg
#   inflating: images/1150.jpg
#   inflating: images/3974.jpg
#   inflating: images/2008.jpg
#   inflating: images/24947.jpg
#   inflating: images/31707.jpg
#   inflating: images/8442.jpg
#   inflating: images/23819.jpg
#   inflating: images/12912.jpg
#   inflating: images/17793.jpg
#   inflating: images/5971.jpg
#   inflating: images/20535.jpg
#   inflating: images/24951.jpg
#   inflating: images/24063.jpg
#   inflating: images/23999.jpg
#   inflating: images/28373.jpg
#   inflating: images/31158.jpg
#   inflating: images/198.jpg
#   inflating: images/36494.jpg
#   inflating: images/2118.jpg
#   inflating: images/16683.jpg
#   inflating: images/29865.jpg
#   inflating: images/22344.jpg
#   inflating: images/4149.jpg
#   inflating: images/24730.jpg
#   inflating: images/23720.jpg
#   inflating: images/31618.jpg
#   inflating: images/33126.jpg
#   inflating: images/31246.jpg
#   inflating: images/27394.jpg
#   inflating: images/5163.jpg
#   inflating: images/28702.jpg
#   inflating: images/26150.jpg
#   inflating: images/15357.jpg
#   inflating: images/20516.jpg
#   inflating: images/15242.jpg
#   inflating: images/7335.jpg
#   inflating: images/14398.jpg
#   inflating: images/17385.jpg
#   inflating: images/11013.jpg
#   inflating: images/9885.jpg

# %%
# 3) Display one image in the training set and the associated size
# We here chose to display   

# image1 = 34985.jpg 
image1 = plt.imread("gan_class_images/images/822.jpg")
plt.imshow(image1)
plt.show()
print(image1.shape)

# image2 = 240.jpg
# Out:
# (64, 64, 3)

# %%
# 4) Prepare the MangaFace Dataset as training set with the help of *class*

class MangaFace(Dataset):
    def __init__(self, root, transform=None):
        """Initialize Pokemon."""
        self.transform = transform
        self.root = root
        self.imgs = glob.glob(self.root + '*')

    def __getitem__(self, idx):
        """Get item from Pokemon class.
        Args:
            index (int): Index
        Returns:
            img: PIL Image.
        """
        img = self.imgs[idx]
        img = Image.open(img).convert('RGB')

        if self.transform is not None:
            img = self.transform(img)

        return img

    def __len__(self):
        """Get length."""
        return len(self.imgs)

# %%
# 5) Show the size of the training set

# normalize all image included on the loaded dataset : 
train_transform = transforms.Compose([
                                      transforms.Resize((64,64)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Define the trainset thanks to MangaFace :
trainset = MangaFace(root='./gan_class_images/images/', transform=train_transform)

# Show the size :
print("Size of the training set : ",len(trainset))
# Out:
# Size of the training set :  36740

# %% [markdown]
# ### Define Generator and Discriminator networks
#
# Preliminary work :
#
# 1) Define parameters
#
# 2) Set device - using GPU
#
# 3) Network weights initialization

# %%
# 1) Define parameters 

batch_size = 128  # or other 64, 32 
beta1 = 0.5       # for the optimization function 
lr = 2e-4         # learning rate 
nz = 100          # input dimension 
num_epochs = 100  # trainings 
num_workers = 8

# %%
# 2) Set device - we use GPU 
device = torch.device("cuda:0")

# %%
# 3) Network weights initialization 
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)      # N(0,0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)      # N(1,0.02)
        m.bias.data.fill_(0)

# %% [markdown]
# ### 2. Generator Network
#
#
# For this project :
#
#   > input size: batchsize * 100 * 1 * 1
#
#   > output size: batchsize * 3 * 64 * 64
#
#
#   In oder to generate image from the input noise, we use the operator **ConvTranspose2d** to upsample spatial dimension :
#
#     nn.ConvTranspose2d(in-channels , out-channels, kernel-size, stride, padding)
#
# 1) Define the Generator Network
#
# 2) Test the Generator

# %%
# Summary of the generator : 
"""
* 1st layer:
transposed convolution
batch norm
relu

* 2nd layer
transposed convolution
batch norm
relu

* 3rd layer
transposed convolution
batch norm
relu

* 4th layer
transposed convolution
batch norm
relu

* 5th layer
transposed convolution
tanh
"""


# 1) Define the Generator Network
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # TODO:

          # input = bs * 100 * 1 * 1
          # output = bs * 3 * 64 * 64

        # Help of the Sequential module   
        self.net = nn.Sequential(   
        # 1st layer output: bs * 512 * 4 * 4
          nn.ConvTranspose2d(100, 512, 4, 1, 0, bias=True),
          nn.BatchNorm2d(512),
          nn.ReLU(inplace=True),
        # 2nd layer output: bs * 256 * 8 * 8    
          nn.ConvTranspose2d(512, 256, 4, 2, 1),
          nn.BatchNorm2d(256),
          nn.ReLU(inplace=True),
        # 3rd layer output: bs * 128 * 16 * 16
          nn.ConvTranspose2d(256, 128, 4, 2, 1),
          nn.BatchNorm2d(128),
          nn.ReLU(True),
        # 4th layer output: bs * 64 * 32 * 32
          nn.ConvTranspose2d(128, 64, 4, 2, 1),
          nn.BatchNorm2d(64),
          nn.ReLU(True),
        # 5th layer output: bs * 3 * 64 * 64
          nn.ConvTranspose2d(64, 3, 4, 2, 1),
          nn.Tanh()
        )
    def forward(self, x):
      
        out = self.net(x)

        return out

# %%
net = Generator()
print(net)
# Out:
# Generator(
#   (net): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (13): Tanh()
#   )
# )

# %%
# 2) Test the Generator
# input : 8 tensor with 100 channels of 1x1 
z = torch.randn(8, 100, 1, 1)

net = Generator()
# output through the Generator "net" : 8 tensor with 3 channels (RGB) of 64x64
out = net(z) # 8 * 3 * 64 * 64

# shape of the out through the Generator ? 
print(out.shape)
# Out:
# torch.Size([8, 3, 64, 64])

# %% [markdown]
# ### 2. Discriminator Network
#
# The discriminator take as input a real data or a generated data and perform a binary classification.
#
#   > input size:  batchsize * 3 * 64 * 64
#
#   > output size: batchsize * 1
#
#
# 1) Define the Discriminator Network
#
# 2) Test the Discriminator

# %%
# Summary of the discriminator : 
"""
* 1st layer:
convolution
Leakyrelu

* 2nd layer
convolution
batch norm
Leakyrelu

* 3rd layer
convolution
batch norm
Leakyrelu

* 4th layer
convolution
batch norm
Leakyrelu

* 5th layer
convolution
sigmoid
"""


# 1) Define the Discriminator Network

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.net = nn.Sequential(
        # 1st layer output: bs * 64 * 32 * 32
          nn.Conv2d(3, 64, 4, 2, 1),
          #nn.ReLU(True),
          nn.LeakyReLU(0.2, True),
        # 2nd layer output: bs * 128 * 16 * 16    
          nn.Conv2d(64, 128, 4, 2, 1),
          nn.BatchNorm2d(128),
          nn.LeakyReLU(0.2, True),
        # 3rd layer output: bs * 256 * 8 * 8
          nn.Conv2d(128, 256, 4, 2, 1),
          nn.BatchNorm2d(256),
          nn.LeakyReLU(0.2, True),
        # 4th layer output: bs * 512 * 4 * 4
          nn.Conv2d(256, 512, 4, 2, 1),
          nn.BatchNorm2d(512),
          nn.LeakyReLU(0.2, True),
        # 5th layer output: bs * 1
          nn.Conv2d(512, 1, 4, 1, 0),
          nn.Sigmoid()
        )
    def forward(self, x):

        out = self.net(x)

        return out.squeeze(-1).squeeze(-1)

# %%
# 2) Test the Discriminator
# input : 4 tensor with 3 channels of 64x64 
x = torch.randn(4, 3, 64, 64)

net = Discriminator()
# output through the Discriminator "net" : 
out = net(x) 
print(out.size()) # 4 * 1
# Out:
# torch.Size([4, 1])

# %% [markdown]
# ### Display Function

# %%
def display_demos(fixed_noise, epoch, iters):
  img_list = []
  with torch.no_grad():
    fake = netG(fixed_noise).detach().cpu()
    plt.rcParams["figure.figsize"]=10,10
    plt.clf()
    plt.title('epoch: %d iteration: %d'%(epoch, iters))
    imgs = make_grid(fake.data*0.5+0.5).cpu() # CHW
    plt.imshow(imgs.permute(1,2,0).numpy())
    display.display(plt.gcf())
    display.clear_output(wait=True)
    time.sleep(1.0)

# %% [markdown]
# ### Main for G and D

# %%
# define G, D and initialize parameters
# attention: put it into GPU
netG = Generator().to(device)
netD = Discriminator().to(device)
netG.apply(weights_init)
netD.apply(weights_init)
# Out:
# Discriminator(
#   (net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1))
#     (12): Sigmoid()
#   )
# )

# %% [markdown]
# ### 4. Generator - Discriminator Loss

# %%
# define loss function 
# hint: binary cross entropy
criterion = nn.BCELoss().to(device)

# %%
#img_list for loss
G_losses = []
D_losses = []
iters = 0

# %% [markdown]
# ### 5. Optimizer

# %%
# Create batch of latent vectors (64 * nz * 1 * 1) that we will use to visualize
# hint: torch.randn
fixed_noise = torch.randn(64, 100, 1, 1).to(device)

# %%
# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %% [markdown]
# ### 6. Train

# %%
dataset = MangaFace(root='./gan_class_images/images/', transform=train_transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)


print("==> start training")
for epoch in range(num_epochs):
  # For each batch in the dataloader
  for i, data in enumerate(dataloader):
    ############################
    # Update D network
    # maximize log(D(x)) + log(1 - D(G(z)))
    ###########################
    # put data into gpu
    real_imgs = data.to(device)

    ## Train with all-real batches
    # set D gradient 0
    netD.zero_grad()

    # Forward pass real batch through D
    output = netD(real_imgs)

    # set ground truth label 1
    label_real = torch.ones(output.size()).to(device)

    # Calculate loss on all-real batch
    errD_real = criterion(output, label_real)

    # Calculate gradients for D in backward pass
    errD_real.backward()

    ## Train with all-fake batch
    # Generate batch of latent vectors
    noises = torch.randn(output.size(0), 100, 1, 1).to(device)

    # Generate fake image batch with G
    fake = netG(noises)

    # Classify all fake batch with D
    output = netD(fake.detach())

    # set ground truth label 0
    label_fake = torch.zeros(output.size()).to(device)

    # Calculate D's loss on the all-fake batch
    errD_fake = criterion(output, label_fake)

    # Calculate the gradients for this batch
    errD_fake.backward()

    # Add the gradients from the all-real and all-fake batches
    errD = errD_real + errD_fake

    # Update D
    optimizerD.step()

    ############################
    # Update G network
    # maximize log(D(G(z)))
    ###########################
    # set G gradient 0
    netG.zero_grad()

    # Since we just updated D, perform another forward pass of all-fake batch through D
    output = netD(fake)

    # Calculate G's loss based on this output
    errG = criterion(output, label_real)

    # Calculate gradients for G
    errG.backward()

    # Update G
    optimizerG.step()

    # Save Losses for plotting later
    G_losses.append(errG.item())
    D_losses.append(errD.item())

    # display demo images each 50 iterations
    if iters % 50 == 0:
      display_demos(fixed_noise, epoch, iters)

    iters += 1

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses,label="G")
plt.plot(D_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
